# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import Dependencies
import pandas as pd
import numpy as np
from citipy import citipy as citipy
import requests
import time

# Import the API key.
from config import weather_api_key

# %% [markdown]
# ## Generate Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %% [markdown]
# ## API Call with OpenWeatherMap

# %%
# Starting/Base URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | atar
# Processing Record 4 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 1 | fairbanks
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | iskateley
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | severo-kurilsk
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | krasnoselkup
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | kpandae
# Processing Record 15 of Set 1 | lancaster
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | tunoshna
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | tessalit
# Processing Record 24 of Set 1 | camocim
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | eucaliptus
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | husavik
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | ahipara
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | qingdao
# Processing Record 34 of Set 1 | sarkand
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | northam
# Processing Record 38 of Set 1 | urucara
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | maningrida
# Processing Record 42 of Set 1 | deputatskiy
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | kayes
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | mayo
# Processing Record 50 of Set 1 | rio grande
# Processing Record 1 of Set 2 | beringovskiy
# Processing Record 2 of Set 2 | vanavara
# Processing Record 3 of Set 2 | barranca
# Processing Record 4 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | maiduguri
# Processing Record 9 of Set 2 | kenora
# Processing Record 10 of Set 2 | altay
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | otane
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | port augusta
# Processing Record 15 of Set 2 | yerbogachen
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | cockburn town
# Processing Record 18 of Set 2 | innisfail
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | meadow lake
# Processing Record 21 of Set 2 | shingu
# Processing Record 22 of Set 2 | waipawa
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | gravelbourg
# Processing Record 26 of Set 2 | nishihara
# Processing Record 27 of Set 2 | asekeyevo
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | abnub
# Processing Record 32 of Set 2 | mount gambier
# Processing Record 33 of Set 2 | jackson
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | meulaboh
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | korocha
# Processing Record 42 of Set 2 | lovozero
# Processing Record 43 of Set 2 | minot
# Processing Record 44 of Set 2 | los llanos de aridane
# Processing Record 45 of Set 2 | tursunzoda
# Processing Record 46 of Set 2 | vanimo
# Processing Record 47 of Set 2 | thunder bay
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | malanje
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | ucluelet
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | leningradskiy
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | boa vista
# Processing Record 8 of Set 3 | hornepayne
# Processing Record 9 of Set 3 | palmer
# Processing Record 10 of Set 3 | general jose eduvigis diaz
# Processing Record 11 of Set 3 | ponazyrevo
# Processing Record 12 of Set 3 | amta
# Processing Record 13 of Set 3 | ayios matthaios
# City not found. Skipping...
# Processing Record 14 of Set 3 | vila velha
# Processing Record 15 of Set 3 | fiumicino
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | korla
# Processing Record 18 of Set 3 | eydhafushi
# Processing Record 19 of Set 3 | sonqar
# City not found. Skipping...
# Processing Record 20 of Set 3 | maracana
# Processing Record 21 of Set 3 | atambua
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | xining
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | makakilo city
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | zheleznodorozhnyy
# Processing Record 30 of Set 3 | burnie
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | savannah bight
# Processing Record 33 of Set 3 | maarianhamina
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | coquimbo
# Processing Record 36 of Set 3 | pontianak
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | havoysund
# Processing Record 40 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | khatanga
# Processing Record 42 of Set 3 | bredasdorp
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | kuliyapitiya
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | eldorado
# Processing Record 47 of Set 3 | thinadhoo
# Processing Record 48 of Set 3 | amazar
# Processing Record 49 of Set 3 | gollere
# City not found. Skipping...
# Processing Record 50 of Set 3 | byron bay
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | skibbereen
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 4 | banda aceh
# Processing Record 9 of Set 4 | waw
# Processing Record 10 of Set 4 | muhos
# Processing Record 11 of Set 4 | sistranda
# Processing Record 12 of Set 4 | moyale
# Processing Record 13 of Set 4 | srandakan
# Processing Record 14 of Set 4 | magadan
# Processing Record 15 of Set 4 | arkhangelos
# City not found. Skipping...
# Processing Record 16 of Set 4 | mahajanga
# Processing Record 17 of Set 4 | barra patuca
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | albina
# Processing Record 20 of Set 4 | yellowknife
# Processing Record 21 of Set 4 | burica
# City not found. Skipping...
# Processing Record 22 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 4 | shelburne
# Processing Record 24 of Set 4 | agucadoura
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 4 | roald
# Processing Record 28 of Set 4 | ayorou
# Processing Record 29 of Set 4 | avera
# Processing Record 30 of Set 4 | sur
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | esperance
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | bom jesus da lapa
# Processing Record 35 of Set 4 | puerto rondon
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | launceston
# Processing Record 38 of Set 4 | mwingi
# Processing Record 39 of Set 4 | beira
# Processing Record 40 of Set 4 | lamu
# Processing Record 41 of Set 4 | sakakah
# Processing Record 42 of Set 4 | port elizabeth
# Processing Record 43 of Set 4 | cabinda
# Processing Record 44 of Set 4 | leh
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | katsuura
# Processing Record 47 of Set 4 | karratha
# Processing Record 48 of Set 4 | covington
# Processing Record 49 of Set 4 | whitehorse
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | kirovskiy
# Processing Record 3 of Set 5 | jamiltepec
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | saint-francois
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | ust-nera
# Processing Record 8 of Set 5 | pimenta bueno
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | nandigama
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | rosarito
# Processing Record 13 of Set 5 | castanos
# Processing Record 14 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 5 | lagoa
# Processing Record 16 of Set 5 | mar del plata
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | lorengau
# Processing Record 19 of Set 5 | puerto carreno
# Processing Record 20 of Set 5 | dakar
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | kashiwazaki
# Processing Record 23 of Set 5 | butajira
# Processing Record 24 of Set 5 | agutaya
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | ossora
# Processing Record 27 of Set 5 | dicabisagan
# Processing Record 28 of Set 5 | bethel
# Processing Record 29 of Set 5 | bazarnyye mataki
# Processing Record 30 of Set 5 | pitimbu
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | olavarria
# Processing Record 33 of Set 5 | berlevag
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | tautira
# Processing Record 37 of Set 5 | vostok
# Processing Record 38 of Set 5 | puerto leguizamo
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | beroroha
# Processing Record 42 of Set 5 | westport
# Processing Record 43 of Set 5 | toccoa
# Processing Record 44 of Set 5 | chicama
# Processing Record 45 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 5 | hazaribag
# Processing Record 47 of Set 5 | behbahan
# Processing Record 48 of Set 5 | tarakan
# Processing Record 49 of Set 5 | sovetskiy
# Processing Record 50 of Set 5 | vila franca do campo
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | oranjestad
# Processing Record 3 of Set 6 | maniitsoq
# Processing Record 4 of Set 6 | keffi
# Processing Record 5 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 6 | keti bandar
# Processing Record 7 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 6 | asau
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | butterworth
# Processing Record 11 of Set 6 | iraan
# Processing Record 12 of Set 6 | necochea
# Processing Record 13 of Set 6 | hay river
# Processing Record 14 of Set 6 | sao filipe
# Processing Record 15 of Set 6 | auriflama
# Processing Record 16 of Set 6 | santa maria
# Processing Record 17 of Set 6 | sinnamary
# Processing Record 18 of Set 6 | adrar
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | oyotun
# Processing Record 21 of Set 6 | payo
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | pauini
# Processing Record 24 of Set 6 | akhnur
# Processing Record 25 of Set 6 | torrington
# Processing Record 26 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 6 | casablanca
# Processing Record 28 of Set 6 | touros
# Processing Record 29 of Set 6 | half moon bay
# Processing Record 30 of Set 6 | najran
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | mandan
# Processing Record 33 of Set 6 | kungurtug
# Processing Record 34 of Set 6 | kentau
# Processing Record 35 of Set 6 | inta
# Processing Record 36 of Set 6 | raga
# Processing Record 37 of Set 6 | kalat
# Processing Record 38 of Set 6 | mikhaylovka
# Processing Record 39 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 6 | manzanillo
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | guarapari
# Processing Record 43 of Set 6 | golspie
# Processing Record 44 of Set 6 | ponta do sol
# Processing Record 45 of Set 6 | caraballeda
# Processing Record 46 of Set 6 | kirovskaya
# Processing Record 47 of Set 6 | amuntai
# Processing Record 48 of Set 6 | saldanha
# Processing Record 49 of Set 6 | tuy hoa
# Processing Record 50 of Set 6 | amontada
# Processing Record 1 of Set 7 | aloleng
# Processing Record 2 of Set 7 | bay roberts
# Processing Record 3 of Set 7 | moerai
# Processing Record 4 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | macau
# Processing Record 7 of Set 7 | vestmanna
# Processing Record 8 of Set 7 | srednekolymsk
# Processing Record 9 of Set 7 | mezen
# Processing Record 10 of Set 7 | swan river
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | baker city
# Processing Record 13 of Set 7 | pierre
# Processing Record 14 of Set 7 | fallon
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | wuwei
# Processing Record 17 of Set 7 | loukhi
# Processing Record 18 of Set 7 | hagere selam
# Processing Record 19 of Set 7 | baie-comeau
# Processing Record 20 of Set 7 | hackensack
# Processing Record 21 of Set 7 | aksu
# Processing Record 22 of Set 7 | mildura
# Processing Record 23 of Set 7 | moron
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | bundaberg
# Processing Record 27 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | champerico
# Processing Record 30 of Set 7 | benghazi
# Processing Record 31 of Set 7 | hovd
# Processing Record 32 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 7 | picota
# Processing Record 35 of Set 7 | omsukchan
# Processing Record 36 of Set 7 | bismarck
# Processing Record 37 of Set 7 | perth
# Processing Record 38 of Set 7 | walvis bay
# Processing Record 39 of Set 7 | dunedin
# Processing Record 40 of Set 7 | mezhdurechensk
# Processing Record 41 of Set 7 | remedios
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | kijang
# Processing Record 44 of Set 7 | wajir
# Processing Record 45 of Set 7 | constantine
# Processing Record 46 of Set 7 | agapovka
# Processing Record 47 of Set 7 | tigil
# Processing Record 48 of Set 7 | anse-bertrand
# Processing Record 49 of Set 7 | bagado
# Processing Record 50 of Set 7 | amalapuram
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | nuuk
# Processing Record 3 of Set 8 | kinango
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | bonfim
# Processing Record 6 of Set 8 | corner brook
# Processing Record 7 of Set 8 | fare
# Processing Record 8 of Set 8 | labuhan
# Processing Record 9 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 8 | boshan
# Processing Record 11 of Set 8 | abu samrah
# Processing Record 12 of Set 8 | biltine
# Processing Record 13 of Set 8 | totness
# Processing Record 14 of Set 8 | fort nelson
# Processing Record 15 of Set 8 | vao
# Processing Record 16 of Set 8 | kasempa
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | heihe
# Processing Record 19 of Set 8 | tkibuli
# Processing Record 20 of Set 8 | okhotsk
# Processing Record 21 of Set 8 | souillac
# Processing Record 22 of Set 8 | gaoua
# Processing Record 23 of Set 8 | san cristobal
# Processing Record 24 of Set 8 | alofi
# Processing Record 25 of Set 8 | mecca
# Processing Record 26 of Set 8 | maceio
# Processing Record 27 of Set 8 | howard springs
# Processing Record 28 of Set 8 | huinan
# Processing Record 29 of Set 8 | sao joao da barra
# Processing Record 30 of Set 8 | serenje
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | sakaiminato
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | nelson bay
# Processing Record 35 of Set 8 | roma
# Processing Record 36 of Set 8 | xiamen
# Processing Record 37 of Set 8 | kruisfontein
# Processing Record 38 of Set 8 | santa rosa
# Processing Record 39 of Set 8 | salina cruz
# Processing Record 40 of Set 8 | jaslo
# Processing Record 41 of Set 8 | turukhansk
# Processing Record 42 of Set 8 | sibay
# Processing Record 43 of Set 8 | zhuhai
# Processing Record 44 of Set 8 | phan thiet
# Processing Record 45 of Set 8 | agva
# City not found. Skipping...
# Processing Record 46 of Set 8 | aguas belas
# Processing Record 47 of Set 8 | rabo de peixe
# Processing Record 48 of Set 8 | sibolga
# Processing Record 49 of Set 8 | tongliao
# Processing Record 50 of Set 8 | chokurdakh
# Processing Record 1 of Set 9 | washougal
# Processing Record 2 of Set 9 | mulege
# Processing Record 3 of Set 9 | buala
# Processing Record 4 of Set 9 | diego de almagro
# Processing Record 5 of Set 9 | yeppoon
# Processing Record 6 of Set 9 | pineville
# Processing Record 7 of Set 9 | port alfred
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | wasilla
# Processing Record 10 of Set 9 | ugoofaaru
# Processing Record 11 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 9 | batagay-alyta
# Processing Record 14 of Set 9 | bluefield
# Processing Record 15 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 9 | weinan
# Processing Record 17 of Set 9 | sulat
# Processing Record 18 of Set 9 | little current
# Processing Record 19 of Set 9 | fukue
# Processing Record 20 of Set 9 | mercedes
# Processing Record 21 of Set 9 | hasaki
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | carutapera
# Processing Record 24 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 9 | koslan
# Processing Record 26 of Set 9 | herat
# Processing Record 27 of Set 9 | skeldon
# Processing Record 28 of Set 9 | ylivieska
# Processing Record 29 of Set 9 | oranjemund
# Processing Record 30 of Set 9 | zaraza
# Processing Record 31 of Set 9 | tingi
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | awbari
# Processing Record 34 of Set 9 | farkhor
# Processing Record 35 of Set 9 | ostrovnoy
# Processing Record 36 of Set 9 | pundaguitan
# Processing Record 37 of Set 9 | sarai
# Processing Record 38 of Set 9 | krasnoyarskiy
# Processing Record 39 of Set 9 | prince rupert
# Processing Record 40 of Set 9 | adre
# Processing Record 41 of Set 9 | cabedelo
# Processing Record 42 of Set 9 | buritizeiro
# Processing Record 43 of Set 9 | seminole
# Processing Record 44 of Set 9 | stornoway
# Processing Record 45 of Set 9 | mega
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | japura
# Processing Record 48 of Set 9 | khani
# Processing Record 49 of Set 9 | nantucket
# Processing Record 50 of Set 9 | tygda
# Processing Record 1 of Set 10 | tukrah
# Processing Record 2 of Set 10 | inhambane
# Processing Record 3 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | san pedro
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | port lincoln
# Processing Record 7 of Set 10 | custoias
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | mahibadhoo
# Processing Record 10 of Set 10 | anloga
# Processing Record 11 of Set 10 | neuquen
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | salinopolis
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | porosozero
# Processing Record 16 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 10 | chuy
# Processing Record 18 of Set 10 | binzhou
# Processing Record 19 of Set 10 | high prairie
# Processing Record 20 of Set 10 | sijunjung
# Processing Record 21 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 10 | skorping
# Processing Record 24 of Set 10 | raska
# Processing Record 25 of Set 10 | kirakira
# Processing Record 26 of Set 10 | allende
# Processing Record 27 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 10 | tinskoy
# Processing Record 29 of Set 10 | honiara
# Processing Record 30 of Set 10 | suileng
# Processing Record 31 of Set 10 | san jose
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | riyadh
# Processing Record 34 of Set 10 | arona
# Processing Record 35 of Set 10 | berdigestyakh
# Processing Record 36 of Set 10 | griffith
# Processing Record 37 of Set 10 | lata
# Processing Record 38 of Set 10 | beeville
# Processing Record 39 of Set 10 | sola
# Processing Record 40 of Set 10 | ixtapa
# Processing Record 41 of Set 10 | abha
# Processing Record 42 of Set 10 | hamilton
# Processing Record 43 of Set 10 | amberley
# Processing Record 44 of Set 10 | la primavera
# Processing Record 45 of Set 10 | kluczbork
# Processing Record 46 of Set 10 | loiza
# Processing Record 47 of Set 10 | celestun
# Processing Record 48 of Set 10 | kununurra
# Processing Record 49 of Set 10 | belyy yar
# Processing Record 50 of Set 10 | gizo
# Processing Record 1 of Set 11 | orlik
# Processing Record 2 of Set 11 | weligama
# Processing Record 3 of Set 11 | telhara
# Processing Record 4 of Set 11 | seredka
# Processing Record 5 of Set 11 | suntar
# Processing Record 6 of Set 11 | quesnel
# Processing Record 7 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 11 | gat
# Processing Record 9 of Set 11 | rassvet
# Processing Record 10 of Set 11 | dudinka
# Processing Record 11 of Set 11 | nizhniy kuranakh
# Processing Record 12 of Set 11 | kuznechnoye
# Processing Record 13 of Set 11 | namibe
# Processing Record 14 of Set 11 | hambantota
# Processing Record 15 of Set 11 | am timan
# Processing Record 16 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 17 of Set 11 | buraydah
# Processing Record 18 of Set 11 | xuddur
# Processing Record 19 of Set 11 | albenga
# Processing Record 20 of Set 11 | loyga
# Processing Record 21 of Set 11 | kunnamangalam
# Processing Record 22 of Set 11 | sieradz
# Processing Record 23 of Set 11 | yithion
# City not found. Skipping...
# Processing Record 24 of Set 11 | foumbot
# Processing Record 25 of Set 11 | viedma
# Processing Record 26 of Set 11 | colares
# Processing Record 27 of Set 11 | evensk
# Processing Record 28 of Set 11 | santa cruz
# Processing Record 29 of Set 11 | isiro
# Processing Record 30 of Set 11 | paracuru
# Processing Record 31 of Set 11 | mozarlandia
# Processing Record 32 of Set 11 | yar-sale
# Processing Record 33 of Set 11 | tazovskiy
# Processing Record 34 of Set 11 | afanasyevo
# City not found. Skipping...
# Processing Record 35 of Set 11 | shar
# Processing Record 36 of Set 11 | sahuaripa
# Processing Record 37 of Set 11 | puerto vallarta
# Processing Record 38 of Set 11 | bartica
# Processing Record 39 of Set 11 | konstantinovsk
# Processing Record 40 of Set 11 | portland
# Processing Record 41 of Set 11 | manokwari
# Processing Record 42 of Set 11 | piacabucu
# Processing Record 43 of Set 11 | haines junction
# Processing Record 44 of Set 11 | naze
# Processing Record 45 of Set 11 | quang ngai
# Processing Record 46 of Set 11 | tena
# Processing Record 47 of Set 11 | conceicao do mato dentro
# Processing Record 48 of Set 11 | bukama
# Processing Record 49 of Set 11 | gudiyattam
# City not found. Skipping...
# Processing Record 50 of Set 11 | wolow
# Processing Record 1 of Set 12 | huntington
# Processing Record 2 of Set 12 | tucumcari
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | road town
# Processing Record 5 of Set 12 | port hardy
# Processing Record 6 of Set 12 | bida
# Processing Record 7 of Set 12 | talaya
# Processing Record 8 of Set 12 | safaga
# Processing Record 9 of Set 12 | algiers
# Processing Record 10 of Set 12 | gushikawa
# Processing Record 11 of Set 12 | bialystok
# Processing Record 12 of Set 12 | antofagasta
# Processing Record 13 of Set 12 | vytegra
# Processing Record 14 of Set 12 | qurayyat
# Processing Record 15 of Set 12 | cogoleto
# Processing Record 16 of Set 12 | okha
# Processing Record 17 of Set 12 | cotonou
# Processing Record 18 of Set 12 | visnes
# Processing Record 19 of Set 12 | tyukalinsk
# Processing Record 20 of Set 12 | scarborough
# Processing Record 21 of Set 12 | zilair
# Processing Record 22 of Set 12 | general roca
# Processing Record 23 of Set 12 | lokosovo
# Processing Record 24 of Set 12 | lakes entrance
# Processing Record 25 of Set 12 | new castle
# Processing Record 26 of Set 12 | sicamous
# Processing Record 27 of Set 12 | saskylakh
# Processing Record 28 of Set 12 | costinesti
# Processing Record 29 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 30 of Set 12 | ranfurly
# Processing Record 31 of Set 12 | iracoubo
# Processing Record 32 of Set 12 | comodoro rivadavia
# Processing Record 33 of Set 12 | malindi
# Processing Record 34 of Set 12 | osmena
# Processing Record 35 of Set 12 | sile
# Processing Record 36 of Set 12 | aseri
# Processing Record 37 of Set 12 | doha
# Processing Record 38 of Set 12 | lake cowichan
# Processing Record 39 of Set 12 | popondetta
# Processing Record 40 of Set 12 | zabaykalsk
# Processing Record 41 of Set 12 | grindavik
# Processing Record 42 of Set 12 | tramore
# Processing Record 43 of Set 12 | eyl
# Processing Record 44 of Set 12 | narrabri
# Processing Record 45 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 46 of Set 12 | asfi
# Processing Record 47 of Set 12 | shilka
# Processing Record 48 of Set 12 | kaspiyskiy
# Processing Record 49 of Set 12 | harlingen
# Processing Record 50 of Set 12 | rapar
# Processing Record 1 of Set 13 | christchurch
# Processing Record 2 of Set 13 | maturin
# Processing Record 3 of Set 13 | flin flon
# Processing Record 4 of Set 13 | taganak
# Processing Record 5 of Set 13 | sao jose de piranhas
# Processing Record 6 of Set 13 | oia
# Processing Record 7 of Set 13 | broken hill
# Processing Record 8 of Set 13 | lavrentiya
# Processing Record 9 of Set 13 | totolapan
# Processing Record 10 of Set 13 | aasiaat
# Processing Record 11 of Set 13 | yelizovo
# Processing Record 12 of Set 13 | kargasok
# Processing Record 13 of Set 13 | buzovna
# Processing Record 14 of Set 13 | chenzhou
# Processing Record 15 of Set 13 | volax
# Processing Record 16 of Set 13 | dingle
# Processing Record 17 of Set 13 | qui nhon
# Processing Record 18 of Set 13 | hofn
# Processing Record 19 of Set 13 | miquelon
# Processing Record 20 of Set 13 | manali
# Processing Record 21 of Set 13 | ocos
# Processing Record 22 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 13 | kiruna
# Processing Record 24 of Set 13 | novoagansk
# Processing Record 25 of Set 13 | garden city
# Processing Record 26 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 13 | zvishavane
# Processing Record 28 of Set 13 | jijiang
# Processing Record 29 of Set 13 | pacific grove
# Processing Record 30 of Set 13 | charters towers
# Processing Record 31 of Set 13 | north bend
# Processing Record 32 of Set 13 | rock sound
# Processing Record 33 of Set 13 | homer
# Processing Record 34 of Set 13 | methoni
# Processing Record 35 of Set 13 | akdepe
# Processing Record 36 of Set 13 | hami
# Processing Record 37 of Set 13 | saint-leu
# Processing Record 38 of Set 13 | lazaro cardenas
# Processing Record 39 of Set 13 | dobele
# Processing Record 40 of Set 13 | hohhot
# Processing Record 41 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 13 | temple terrace
# Processing Record 44 of Set 13 | matagami
# Processing Record 45 of Set 13 | kiama
# Processing Record 46 of Set 13 | shangzhi
# Processing Record 47 of Set 13 | tondano
# Processing Record 48 of Set 13 | porto nacional
# Processing Record 49 of Set 13 | praia da vitoria
# Processing Record 50 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 14 | raton
# Processing Record 2 of Set 14 | iquitos
# Processing Record 3 of Set 14 | erenhot
# Processing Record 4 of Set 14 | pahrump
# Processing Record 5 of Set 14 | teahupoo
# Processing Record 6 of Set 14 | sambava
# Processing Record 7 of Set 14 | serebryansk
# Processing Record 8 of Set 14 | kieta
# Processing Record 9 of Set 14 | gayeri
# Processing Record 10 of Set 14 | camacha
# Processing Record 11 of Set 14 | kirovsk
# Processing Record 12 of Set 14 | bhan
# Processing Record 13 of Set 14 | bac lieu
# Processing Record 14 of Set 14 | honningsvag
# Processing Record 15 of Set 14 | san javier
# Processing Record 16 of Set 14 | xacmaz
# Processing Record 17 of Set 14 | irbil
# Processing Record 18 of Set 14 | hirtshals
# Processing Record 19 of Set 14 | batagay
# Processing Record 20 of Set 14 | ojinaga
# Processing Record 21 of Set 14 | nemyriv
# Processing Record 22 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 14 | fengrun
# Processing Record 24 of Set 14 | beisfjord
# Processing Record 25 of Set 14 | van
# Processing Record 26 of Set 14 | tshela
# Processing Record 27 of Set 14 | severnoye
# Processing Record 28 of Set 14 | barinas
# Processing Record 29 of Set 14 | sangar
# Processing Record 30 of Set 14 | netrakona
# Processing Record 31 of Set 14 | saint-joseph
# Processing Record 32 of Set 14 | pinos
# Processing Record 33 of Set 14 | krasnyy chikoy
# Processing Record 34 of Set 14 | san quintin
# Processing Record 35 of Set 14 | jieshi
# Processing Record 36 of Set 14 | rocha
# Processing Record 37 of Set 14 | oum hadjer
# Processing Record 38 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 14 | pedregulho
# Processing Record 40 of Set 14 | tomigusuku
# Processing Record 41 of Set 14 | kadoma
# Processing Record 42 of Set 14 | goderich
# Processing Record 43 of Set 14 | vryburg
# Processing Record 44 of Set 14 | qasigiannguit
# Processing Record 45 of Set 14 | immokalee
# Processing Record 46 of Set 14 | talnakh
# Processing Record 47 of Set 14 | abu dhabi
# Processing Record 48 of Set 14 | soe
# Processing Record 49 of Set 14 | safford
# Processing Record 50 of Set 14 | fergus falls
# Processing Record 1 of Set 15 | madang
# Processing Record 2 of Set 15 | villazon
# Processing Record 3 of Set 15 | xianshuigu
# Processing Record 4 of Set 15 | erzin
# Processing Record 5 of Set 15 | pareora
# Processing Record 6 of Set 15 | keuruu
# Processing Record 7 of Set 15 | hanko
# Processing Record 8 of Set 15 | dauphin
# Processing Record 9 of Set 15 | boca do acre
# Processing Record 10 of Set 15 | tura
# Processing Record 11 of Set 15 | iguape
# Processing Record 12 of Set 15 | bitung
# Processing Record 13 of Set 15 | casambalangan
# Processing Record 14 of Set 15 | kipia
# Processing Record 15 of Set 15 | san jose de guanipa
# Processing Record 16 of Set 15 | itarema
# Processing Record 17 of Set 15 | svetlogorsk
# Processing Record 18 of Set 15 | winneba
# Processing Record 19 of Set 15 | ipojuca
# Processing Record 20 of Set 15 | sawakin
# Processing Record 21 of Set 15 | lufilufi
# Processing Record 22 of Set 15 | gravdal
# Processing Record 23 of Set 15 | cabatuan
# Processing Record 24 of Set 15 | corpus christi
# Processing Record 25 of Set 15 | hervey bay
# Processing Record 26 of Set 15 | kyabe
# Processing Record 27 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 28 of Set 15 | guiuan
# Processing Record 29 of Set 15 | chara
# Processing Record 30 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 15 | porto novo
# Processing Record 33 of Set 15 | uusikaupunki
# Processing Record 34 of Set 15 | jining
# Processing Record 35 of Set 15 | cururupu
# Processing Record 36 of Set 15 | toora-khem
# Processing Record 37 of Set 15 | ndungu
# Processing Record 38 of Set 15 | lethem
# Processing Record 39 of Set 15 | puri
# Processing Record 40 of Set 15 | indian head
# Processing Record 41 of Set 15 | mackay
# Processing Record 42 of Set 15 | bastrop
# Processing Record 43 of Set 15 | severnyy-kospashskiy
# Processing Record 44 of Set 15 | kushiro
# Processing Record 45 of Set 15 | marzuq
# Processing Record 46 of Set 15 | hagi
# Processing Record 47 of Set 15 | tacoronte
# Processing Record 48 of Set 15 | chaman
# Processing Record 49 of Set 15 | manggar
# Processing Record 50 of Set 15 | puerto escondido
# Processing Record 1 of Set 16 | derzhavinsk
# Processing Record 2 of Set 16 | grand gaube
# Processing Record 3 of Set 16 | guatemalita
# City not found. Skipping...
# Processing Record 4 of Set 16 | narasannapeta
# Processing Record 5 of Set 16 | lesnoy
# Processing Record 6 of Set 16 | bardiyah
# Processing Record 7 of Set 16 | weyburn
# Processing Record 8 of Set 16 | lago da pedra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check to see how many cities got weather data
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Create DataFrame and save as .csv

# %%
# Create DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City  Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0    Qaanaaq     -7.94        51          92        8.77     overcast clouds
# 1      Bluff     49.80        78          99       10.89     overcast clouds
# 2       Atar     82.15         9          29       10.36    scattered clouds
# 3  Fairbanks      5.34        63         100        3.44     overcast clouds
# 4  Iskateley     -2.16        99          92        4.72     overcast clouds
#
#   Country      Lat       Lng
# 0      GL  77.4840  -69.3632
# 1      NZ -46.6000  168.3333
# 2      MR  20.5169  -13.0499
# 3      US  64.8378 -147.7164
# 4      RU  67.6803   53.1512

# %%
# Save as .csv to 'Weather_Database' folder
output_data_file = '../Weather_Database/WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label = 'City_ID')
